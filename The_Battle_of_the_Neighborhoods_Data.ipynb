# %% [markdown]
# # The Battle of the Neighborhoods - Data

# %% [markdown]
# ## Data:

# %% [markdown]
# This project will analyse the city of Paris

# %% [markdown]
# The datasets below will be used for this analysis.

# %% [markdown]
# ***Data1*** : **Boroughs and Neighborhoods in Paris**

# %% [markdown]
# Paris has in total 20 boroughs (called *arrondissements* in french) and and 80 neighborhoods. To explore, analyse and segment neighborhoods , longitude and latitude of each neighbor and borough will be added.

# %% [markdown]
# This dataset exist for free on the web.
# Links to the dataset are:
# * https://www.data.gouv.fr/fr/datasets/r/e88c6fda-1d09-42a0-a069-606d3259114e
# * https://opendata.paris.fr/explore/dataset/quartier_paris/download/?format=json&timezone=Europe/Berlin

# %% [markdown]
# ***Data2***: **Population in each borough**

# %% [markdown]
# Numpber of population in each borough will be analysed to find most populous borough in Paris. (more populous Borough = Higher gain).
# The dataset that exists in link below will be used:
# https://www.data.gouv.fr/fr/datasets/r/e88c6fda-1d09-42a0-a069-606d3259114e
# ![population.png](attachment:population.png)
# The table above shows 10 first borough in Paris. Population column considers number of people that live in each borough per 1000 person.

# %% [markdown]
# ***Data3***: **Restaurants in Paris and Markets**

# %% [markdown]
# This data will cover different **restaurants** that already exists in Paris and different **food markets**.
# Analysis of localisation of food markets permits to have an idea of location that will be near to fresh ingredients suppliers.
# This data will be provided by **Foursquare API**. **Foursquare API** permits to provide venues information for each neighborhood in Paris.

# %% [markdown]
# ![Elg-IJOS_400x400.png](attachment:Elg-IJOS_400x400.png)
# source: https://www.google.com/url?sa=i&source=images&cd=&ved=2ahUKEwirs_yQpPvlAhUQqxoKHZSgDaMQjRx6BAgBEAQ&url=https%3A%2F%2Ftwitter.com%2Ffoursquareapi&psig=AOvVaw2VPQomGJpQuIYzK4sWDZ9w&ust=1574424948931233
